# %%
import requests
from bs4 import BeautifulSoup

# %%
url ='https://www.zyte.com/'

request = requests.get(url)
soup = BeautifulSoup(request.text,'html.parser')

# %%
find_first_one = soup.find('a')
first_one_link = find_first_one.get('href')
first_one_text = find_first_one.get_text()

button_name=soup.find('a',id='cta-home-signup-hero-module').get_text()

all_links= soup.find_all('a')
all_links
# Out:
# [<a class="ct-link-text light-link" href="/blog/scrapinghub-is-now-zyte/" id="link_text-139-454" target="_self">Find out why</a>,
#  <a class="ct-link" href="https://app.zyte.com/" id="cta-global-login-top-nav"><div class="ct-text-block font-light label-normal" id="text_block-143-454">Login</div><img alt="zyte login" class="ct-image" id="image-146-454" src="/wp-content/uploads/2020/12/login.svg"/></a>,
#  <a class="ct-link" href="/" id="link-169-454"><img alt="zyte logo" class="ct-image" id="image-8-454" src="/wp-content/uploads/2020/12/Zyte-logo-rgb-website-white.svg"/></a>,
#  <a class="mega-menu-link" href="/data-extraction/" tabindex="0">Data Extraction</a>,
#  <a class="mega-menu-link" href="/smart-proxy-manager/" tabindex="0">Smart Proxy Manager</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="/developers/" tabindex="0">Developers<span class="mega-indicator"></span></a>,
#  <a class="mega-menu-link" href="/developers/">Developers</a>,
# ...
